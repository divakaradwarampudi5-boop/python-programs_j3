# %% [markdown]
# # conditional statementas in python
# 1. python have 4 types of conditional statements
# 2.`if` statement
# 3.`elif` statements
# 4. `nested` statements
# 5. `else` statements
#
# ```python
# if (condition):
#     statements
#     statements..
# ```
#
# ```python if ,else
# if(condition):
#     statements
#     statements...
# else:
#     statements
#     statements...
# ```
#
# ```python if,elif,else
# if(condition):
#     statements
# elif(condition):
#     statement
# else:
#     statements..
# ```

# %%
#write a program to find the given number is even number 
num=int(input("please enter number here:"))
if(num%2 == 0):
    print(num,"is even number")
# Out:
# please enter number here: 125

# %%
#write a program to find the given number is even number or odd number
number= int(input("please enter number here"))
if(number%2 == 0):
    print(number,"is even number" )
else:
    print(number,"is odd number")
# Out:
# please enter number here 6784567948
# 6784567948 is even number

# %%
#write a program to find the given number is positive or negative or zero?
# Program to check if a number is positive, negative, or zero
num = float(input("Enter a number: "))

# Checking conditions
if num > 0:
    print("The number is Positive.")
elif num < 0:
    print("The number is Negative.")
else:
    print("The number is Zero.")
# Out:
# Enter a number:  678
# The number is Positive.

# %%
"""
write a program to find the student grades based on marks 
1.if student marks in between 1000 to 80 then grade is A 
2.if student marks in between 79 to 60 then grade is B
3.if student marks inbetween 59 to 40 then grade is C
4.if student marks are in between 39 to 25 then grade is D
5.if student marks are in between 24 to 0 then grade is fail
6.if other than above marks expected output should be please enter correct marks!
"""
marks=int(input("enter student marks here:"))
if (marks>=80 and marks<=100):
    print(marks,"is A grade")
elif (marks>=60 and marks<=79):
    print(marks,"is B grade")
elif (marks>=40and marks<=59):
     print(marks,"is c grade")
elif (marks>=25 and marks<=39):
     print(marks,"is D grade")
elif (marks>=0 and marks<=24):
     print(marks,"is Fail")
else:
    print(marks,"is not correct marks,please enter correct marks")
# Out:
# <>:15: SyntaxWarning: invalid decimal literal
# <>:15: SyntaxWarning: invalid decimal literal
# /var/folders/55/83z2mhnn2057x3_p72t2ks6m0000gn/T/ipykernel_1519/1899392460.py:15: SyntaxWarning: invalid decimal literal
#   elif (marks>=40and marks<=59):
# enter student marks here: 45
# 45 is c grade

# %%
#write a program to find the leap year or non leap year 
#write a program to check login using conditional satements

# %%
# Program to find the largest among three numbers using max()


num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

largest = max(num1, num2, num3)


print("The largest number is:", largest)
# Out:
# Enter first number:  56726
# Enter second number:  5265
# Enter third number:  24524357896
# The largest number is: 24524357896.0

# %%
year=int(input("enter year here:"))
if (year%4==0):
   if (year%400==0):
       print(year,"is leap year")
   else:
       print(year,"non leap year")
  else
