# %% [markdown]
# # variables in python
# 1.variables memory allocation to a value
# 2.examples are name="shivaji",age=26,salary=10000.55
# # Key points to define variable
# 1. do not start with digit while creating variable
# 2. does not allow special character in a variable
# 3. donot use keywords as variable

# %%
name="vikas"
age=26
salary=10000.55
print(name)
print(age)
print(salary)
# Out:
# vikas
# 26
# 10000.55

# %%
name@="shivaji"
print(name@)
# Out:
#   Cell In[2], line 2
#     print(name@)
#                ^
# SyntaxError: invalid syntax

# %%
for2="vikas"
print(for2)
# Out:
# vikas
